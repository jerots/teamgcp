# %%
import numpy as np
import pandas as pd

import glob
import re

# user='jeremyong'
txt='behminyan'

# %%
users=[]
folders=glob.glob("data/*")

for fd in folders:
    users.append(fd[fd.rfind('/')+1:])
    
print 'USERNAMES:', users
# Out:
# USERNAMES: ['behminyan', 'changsheng', 'jeremyong']

# %%
input = pd.read_csv('data/jeremyong/behminyan_1.csv')
input
# Out:
#     letter   username      down_time     down_x     down_y        up_time  \
# 0        b  jeremyong  1469805445897  61.632653  67.903525  1469805446030
# 1        e  jeremyong  1469805446180  24.489796  13.543599  1469805446297
# 2        h  jeremyong  1469805446397  60.204082  45.825603  1469805446497
# 3    space  jeremyong  1469805446930  50.918367  90.352505  1469805447064
# 4        m  jeremyong  1469805447230  77.142857  64.192950  1469805447347
# 5        i  jeremyong  1469805447481  74.387755  11.502783  1469805447581
# 6        n  jeremyong  1469805447731  71.122449  66.604824  1469805447848
# 7    space  jeremyong  1469805448031  47.040816  92.764378  1469805448115
# 8        y  jeremyong  1469805448215  56.530612  23.005566  1469805448331
# 9        a  jeremyong  1469805448465   7.551020  36.363636  1469805448565
# 10       n  jeremyong  1469805448682  68.469388  65.491651  1469805448765
# 11  return  jeremyong  1469805449382  87.959184  87.384045  1469805449498
#
#          up_x       up_y
# 0   61.632653  67.903525
# 1   24.489796  13.543599
# 2   60.204082  45.825603
# 3   50.918367  90.352505
# 4   77.142857  64.192950
# 5   74.387755  11.502783
# 6   71.122449  66.604824
# 7   47.040816  92.764378
# 8   56.530612  23.005566
# 9    7.551020  36.363636
# 10  68.469388  65.491651
# 11  87.959184  87.384045

# %%
def extractDurations(table):
    letters=table.letter
    DTs=table.down_time
    UTs=table.up_time

    HDlist=[]
    UDDlist=[]
    DDDlist=[]

    for i in range(len(input)):
        holddur=UTs[i]-DTs[i]
        HDlist.append(holddur)

        if(i< len(input)-1):
            updowndur=DTs[i+1]-UTs[i]
            UDDlist.append(updowndur)
#             print holddur+updowndur
            DDDlist.append(holddur+updowndur)
        else:
            UDDlist.append(0)
            DDDlist.append(0)

    return letters, HDlist, UDDlist, DDDlist

# %%
df_rows = []
cols=["text","user"]
letters=""

for user in users:
    filenames=glob.glob("data/"+user+"/"+txt+"*.csv")
    print 'FILENAMES:', filenames
    
    for filename in filenames:

        input = pd.read_csv(filename)
        letters, HDlist, UDDlist, DDDlist = extractDurations(input)
    #     username = re.match(r"(.+)_(.+).csv", filename).groups()[1]

        userrow={}
        userrow['text'] = txt
        userrow['user'] = user

        for i in range(len(letters)):
            if(letters[i] == 'return'):
                break
            userrow['hd'+str(i)+'_'+letters[i]]=HDlist[i]
            userrow['udd'+str(i)+'_'+letters[i]]=UDDlist[i]
            userrow['ddd'+str(i)+'_'+letters[i]]=DDDlist[i]
        df_rows.append(userrow)
    
for i in range(len(letters)): # SOON TO CHANGE
        if(letters[i] == 'return'):
            break
        cols.append('hd'+str(i)+'_'+letters[i])
        cols.append('udd'+str(i)+'_'+letters[i])
        cols.append('ddd'+str(i)+'_'+letters[i])
# Out:
# FILENAMES: ['data/behminyan/behminyan_1.csv', 'data/behminyan/behminyan_2.csv', 'data/behminyan/behminyan_3.csv', 'data/behminyan/behminyan_4.csv', 'data/behminyan/behminyan_5.csv']
# FILENAMES: ['data/changsheng/behminyan_1.csv', 'data/changsheng/behminyan_10.csv', 'data/changsheng/behminyan_2.csv', 'data/changsheng/behminyan_3.csv', 'data/changsheng/behminyan_4.csv', 'data/changsheng/behminyan_5.csv', 'data/changsheng/behminyan_6.csv', 'data/changsheng/behminyan_7.csv', 'data/changsheng/behminyan_8.csv', 'data/changsheng/behminyan_9.csv']
# FILENAMES: ['data/jeremyong/behminyan_1.csv', 'data/jeremyong/behminyan_2.csv', 'data/jeremyong/behminyan_3.csv', 'data/jeremyong/behminyan_4.csv', 'data/jeremyong/behminyan_5.csv']

# %%
combined = pd.DataFrame(df_rows,columns=cols)
combined
# Out:
#          text        user  hd0_b  udd0_b  ddd0_b  hd1_e  udd1_e  ddd1_e  \
# 0   behminyan   behminyan    100      18     118     65      85     150
# 1   behminyan   behminyan    100      18     118     65      85     150
# 2   behminyan   behminyan     83      35     118     50     100     150
# 3   behminyan   behminyan     83      88     171     13      68      81
# 4   behminyan   behminyan     85      33     118     66      68     134
# 5   behminyan  changsheng     98      18     116    118     -16     102
# 6   behminyan  changsheng    117       0     117    135     -67      68
# 7   behminyan  changsheng    100      33     133    135     -33     102
# 8   behminyan  changsheng     82      34     116    134     -32     102
# 9   behminyan  changsheng    100      50     150    117      17     134
# 10  behminyan  changsheng     98      18     116    135     -34     101
# 11  behminyan  changsheng     82      51     133    100     -32      68
# 12  behminyan  changsheng     66      34     100    101     -50      51
# 13  behminyan  changsheng     65      51     116     85     -16      69
# 14  behminyan  changsheng     99      34     133    102       0     102
# 15  behminyan   jeremyong    133     150     283    117     100     217
# 16  behminyan   jeremyong     99     267     366    100     134     234
# 17  behminyan   jeremyong    117     200     317     83     117     200
# 18  behminyan   jeremyong    134     116     250     83     134     217
# 19  behminyan   jeremyong    134     149     283     84     117     201
#
#     hd2_h  udd2_h   ...     ddd7_space  hd8_y  udd8_y  ddd8_y  hd9_a  udd9_a  \
# 0      65     118   ...            217     65      51     116     82      52
# 1      65     118   ...            217     65      51     116     82      52
# 2      49     151   ...            200     67      66     133     82      52
# 3      65     117   ...            217     49      84     133    100      50
# 4      65     134   ...            217     65      51     116     83      84
# 5      63     151   ...            284    115      34     149    149      35
# 6      81     118   ...            233    100      17     117    133      34
# 7      64     134   ...            400     83      34     117    132      51
# 8      65     166   ...            183     82      35     117    133      67
# 9      82     201   ...            181     83      17     100    116      18
# 10     64     151   ...            367     99      18     117    148      85
# 11     64     118   ...            217     66      51     117    115      18
# 12     81      84   ...            234     65      18      83    135       0
# 13     47     118   ...            267     84      16     100    151       0
# 14     48     100   ...            367     83       0      83    133      34
# 15    100     433   ...            184    116     134     250    100     117
# 16     83     267   ...            468     99     150     249    100     117
# 17    116     434   ...            300    100     116     216    100     984
# 18    100     483   ...            200    100      50     150     99    1101
# 19    116     367   ...            233    116      67     183    117     767
#
#     ddd9_a  hd10_n  udd10_n  ddd10_n
# 0      134      65      184      249
# 1      134      65      184      249
# 2      134      82      201      283
# 3      150      67      200      267
# 4      167      49      167      216
# 5      184      82     1033     1115
# 6      167      82      534      616
# 7      183      83      750      833
# 8      200      82      734      816
# 9      134      82      834      916
# 10     233      65      718      783
# 11     133      67      650      717
# 12     135      64      768      832
# 13     151      64      552      616
# 14     167      82      534      616
# 15     217      83      617      700
# 16     217     116      701      817
# 17    1084      84      817      901
# 18    1200     117      500      617
# 19     884     100      517      617
#
# [20 rows x 35 columns]

# %%
# Taken from: https://www.peterbe.com/plog/uniqifiers-benchmark
def unique (seq, idfun=None): # order preserving
    if idfun is None:
        def idfun(x): 
            return x
    seen = {}
    result = []
    for item in seq:
        marker = idfun(item)
        if marker in seen: 
            continue
        seen[marker] = 1
        result.append(item)
    return result

# %%
cats=combined['user'].tolist()
catlist=unique(cats)
print catlist

combined['cat'] = [catlist.index(x) for x in combined.user]
combined
# Out:
# ['behminyan', 'changsheng', 'jeremyong']
#          text        user  hd0_b  udd0_b  ddd0_b  hd1_e  udd1_e  ddd1_e  \
# 0   behminyan   behminyan    100      18     118     65      85     150
# 1   behminyan   behminyan    100      18     118     65      85     150
# 2   behminyan   behminyan     83      35     118     50     100     150
# 3   behminyan   behminyan     83      88     171     13      68      81
# 4   behminyan   behminyan     85      33     118     66      68     134
# 5   behminyan  changsheng     98      18     116    118     -16     102
# 6   behminyan  changsheng    117       0     117    135     -67      68
# 7   behminyan  changsheng    100      33     133    135     -33     102
# 8   behminyan  changsheng     82      34     116    134     -32     102
# 9   behminyan  changsheng    100      50     150    117      17     134
# 10  behminyan  changsheng     98      18     116    135     -34     101
# 11  behminyan  changsheng     82      51     133    100     -32      68
# 12  behminyan  changsheng     66      34     100    101     -50      51
# 13  behminyan  changsheng     65      51     116     85     -16      69
# 14  behminyan  changsheng     99      34     133    102       0     102
# 15  behminyan   jeremyong    133     150     283    117     100     217
# 16  behminyan   jeremyong     99     267     366    100     134     234
# 17  behminyan   jeremyong    117     200     317     83     117     200
# 18  behminyan   jeremyong    134     116     250     83     134     217
# 19  behminyan   jeremyong    134     149     283     84     117     201
#
#     hd2_h  udd2_h ...   hd8_y  udd8_y  ddd8_y  hd9_a  udd9_a  ddd9_a  hd10_n  \
# 0      65     118 ...      65      51     116     82      52     134      65
# 1      65     118 ...      65      51     116     82      52     134      65
# 2      49     151 ...      67      66     133     82      52     134      82
# 3      65     117 ...      49      84     133    100      50     150      67
# 4      65     134 ...      65      51     116     83      84     167      49
# 5      63     151 ...     115      34     149    149      35     184      82
# 6      81     118 ...     100      17     117    133      34     167      82
# 7      64     134 ...      83      34     117    132      51     183      83
# 8      65     166 ...      82      35     117    133      67     200      82
# 9      82     201 ...      83      17     100    116      18     134      82
# 10     64     151 ...      99      18     117    148      85     233      65
# 11     64     118 ...      66      51     117    115      18     133      67
# 12     81      84 ...      65      18      83    135       0     135      64
# 13     47     118 ...      84      16     100    151       0     151      64
# 14     48     100 ...      83       0      83    133      34     167      82
# 15    100     433 ...     116     134     250    100     117     217      83
# 16     83     267 ...      99     150     249    100     117     217     116
# 17    116     434 ...     100     116     216    100     984    1084      84
# 18    100     483 ...     100      50     150     99    1101    1200     117
# 19    116     367 ...     116      67     183    117     767     884     100
#
#     udd10_n  ddd10_n  cat
# 0       184      249    0
# 1       184      249    0
# 2       201      283    0
# 3       200      267    0
# 4       167      216    0
# 5      1033     1115    1
# 6       534      616    1
# 7       750      833    1
# 8       734      816    1
# 9       834      916    1
# 10      718      783    1
# 11      650      717    1
# 12      768      832    1
# 13      552      616    1
# 14      534      616    1
# 15      617      700    2
# 16      701      817    2
# 17      817      901    2
# 18      500      617    2
# 19      517      617    2
#
# [20 rows x 36 columns]

# %% [markdown]
# # Recursive Feature Elimination

# %%
traindata=combined.drop(['text','user','cat'], axis=1).as_matrix(columns=None)
labels=combined['cat'].tolist()

# %%
# Recursive Feature Elimination
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# create a base classifier used to evaluate a subset of attributes
model = LogisticRegression()
# create the RFE model and select 3 attributes
rfe = RFE(model, 3)
# rfe = rfe.fit(dataset.data, dataset.target)
rfe = rfe.fit(traindata, labels)
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False  True False False False False False  True False False False False
#  False  True False False False False False False False False False False
#  False False False False False False False False False]
# [17  1  5 28  4 13 20  1  9 26 21  7 22  1 12 30  8  3 27 11 16 25 29 19 31
#  15 14  6 18 24 23  2 10]

# %%
train_features=['hd0_b', 'udd0_b', 'ddd0_b', 'hd1_e', 'udd1_e', 'ddd1_e', 'hd2_h', 'udd2_h', 'ddd2_h', 'hd3_space', 'udd3_space', 'ddd3_space', 'hd4_m', 'udd4_m', 'ddd4_m', 'hd5_i', 'udd5_i', 'ddd5_i', 'hd6_n', 'udd6_n', 'ddd6_n', 'hd7_space', 'udd7_space', 'ddd7_space', 'hd8_y', 'udd8_y', 'ddd8_y', 'hd9_a', 'udd9_a', 'ddd9_a', 'hd10_n', 'udd10_n', 'ddd10_n']

# %%
res1=pd.DataFrame({'feature': train_features, 'importance':rfe.ranking_}).sort_values(by=['importance'],ascending=True)
res1.head(10)
# Out:
#        feature  importance
# 1       udd0_b           1
# 7       udd2_h           1
# 13      udd4_m           1
# 31     udd10_n           2
# 17      ddd5_i           3
# 4       udd1_e           4
# 2       ddd0_b           5
# 27       hd9_a           6
# 11  ddd3_space           7
# 16      udd5_i           8

# %%
shortlist=res1.head(10)['feature'].tolist()

# %%
shortlist
# Out:
# ['udd0_b',
#  'udd2_h',
#  'udd4_m',
#  'udd10_n',
#  'ddd5_i',
#  'udd1_e',
#  'ddd0_b',
#  'hd9_a',
#  'ddd3_space',
#  'udd5_i']

# %% [markdown]
# # Ensemble Feature Importance

# %%
# Feature Importance
# from sklearn import datasets
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier

# fit an Extra Trees model to the data
model = ExtraTreesClassifier()
model.fit(traindata, labels)
# display the relative importance of each attribute
print(model.feature_importances_)
# Out:
# array([ 0.01894902,  0.04666667,  0.        ,  0.10835458,  0.09911111,
#         0.01066667,  0.        ,  0.02483916,  0.        ,  0.        ,
#         0.        ,  0.        ,  0.09820952,  0.00426667,  0.        ,
#         0.01333333,  0.01666667,  0.02285714,  0.1       ,  0.        ,
#         0.00745098,  0.04      ,  0.00923077,  0.02333333,  0.02791209,
#         0.        ,  0.02666667,  0.0759095 ,  0.08214178,  0.        ,
#         0.        ,  0.09676768,  0.04666667])

# %%
res=pd.DataFrame({'feature':train_features, 'importance':model.feature_importances_}).sort_values(by=['importance'],ascending=False)
res
# Out:
#        feature  importance
# 3        hd1_e    0.108355
# 18       hd6_n    0.100000
# 4       udd1_e    0.099111
# 12       hd4_m    0.098210
# 31     udd10_n    0.096768
# 28      udd9_a    0.082142
# 27       hd9_a    0.075910
# 32     ddd10_n    0.046667
# 1       udd0_b    0.046667
# 21   hd7_space    0.040000
# 24       hd8_y    0.027912
# 26      ddd8_y    0.026667
# 7       udd2_h    0.024839
# 23  ddd7_space    0.023333
# 17      ddd5_i    0.022857
# 0        hd0_b    0.018949
# 16      udd5_i    0.016667
# 15       hd5_i    0.013333
# 5       ddd1_e    0.010667
# 22  udd7_space    0.009231
# 20      ddd6_n    0.007451
# 13      udd4_m    0.004267
# 19      udd6_n    0.000000
# 11  ddd3_space    0.000000
# 10  udd3_space    0.000000
# 14      ddd4_m    0.000000
# 25      udd8_y    0.000000
# 8       ddd2_h    0.000000
# 6        hd2_h    0.000000
# 29      ddd9_a    0.000000
# 30      hd10_n    0.000000
# 2       ddd0_b    0.000000
# 9    hd3_space    0.000000

# %%
print cols
# Out:
# ['text', 'user', 'hd0_b', 'udd0_b', 'ddd0_b', 'hd1_e', 'udd1_e', 'ddd1_e', 'hd2_h', 'udd2_h', 'ddd2_h', 'hd3_space', 'udd3_space', 'ddd3_space', 'hd4_m', 'udd4_m', 'ddd4_m', 'hd5_i', 'udd5_i', 'ddd5_i', 'hd6_n', 'udd6_n', 'ddd6_n', 'hd7_space', 'udd7_space', 'ddd7_space', 'hd8_y', 'udd8_y', 'ddd8_y', 'hd9_a', 'udd9_a', 'ddd9_a', 'hd10_n', 'udd10_n', 'ddd10_n']

# %%
print shortlist
# Out:
# ['udd0_b', 'udd2_h', 'udd4_m', 'udd10_n', 'ddd5_i', 'udd1_e', 'ddd0_b', 'hd9_a', 'ddd3_space', 'udd5_i']

# %% [markdown]
# # Make Summary

# %%
shortlist=['udd0_b', 'udd2_h', 'udd4_m', 'udd10_n', 'ddd5_i', 'udd1_e', 'ddd0_b', 'hd9_a', 'ddd3_space', 'udd5_i']
shortlist.append('user')
dataset=combined[shortlist].drop('user', axis=1).as_matrix(columns=None)
labels=combined['user']

# %%
def separateByClass(dataset,labels):
    separated = {}
    for i in range(len(dataset)):
        vector = dataset[i] # vector = row of data
        label = labels[i]
        if (label not in separated):
            separated[label] = []
        separated[label].append(vector)
    return separated

# %%
sep=separateByClass(dataset,labels)
print sep
# Out:
# {'behminyan': [array([ 18, 118, 134, 184, 183,  85, 118,  82, 217, 118]), array([ 18, 118, 134, 184, 183,  85, 118,  82, 217, 118]), array([ 35, 151, 134, 201, 183, 100, 118,  82, 200, 134]), array([ 88, 117, 134, 200, 183,  68, 171, 100, 201, 118]), array([ 33, 134, 151, 167, 166,  68, 118,  83, 201, 116])], 'changsheng': [array([  18,  151,  135, 1033,  483,  -16,  116,  149,  218,  385]), array([  0, 118, 117, 534, 183, -67, 117, 133, 200,  84]), array([ 33, 134, 117, 750, 233, -33, 133, 132, 401, 118]), array([ 34, 166, 151, 734, 200, -32, 116, 133, 251, 116]), array([ 50, 201, 117, 834, 166,  17, 150, 116, 283,  67]), array([ 18, 151, 119, 718, 166, -34, 116, 148, 551,  68]), array([ 51, 118, 151, 650, 217, -32, 133, 115, 233, 101]), array([ 34,  84,  68, 768, 216, -50, 100, 135, 200, 116]), array([ 51, 118, 134, 552, 167, -16, 116, 151, 200, 100]), array([ 34, 100, 151, 534, 300,   0, 133, 133, 217, 168])], 'jeremyong': [array([150, 433, 134, 617, 250, 100, 283, 100, 300, 150]), array([267, 267, 133, 701, 250, 134, 366, 100, 450, 117]), array([200, 434, 134, 817, 216, 117, 317, 100, 234, 100]), array([116, 483,  84, 500, 200, 134, 250,  99, 184, 100]), array([149, 367, 169, 517, 165, 117, 283, 117, 217, 100])]}

# %%
import math
def mean(numbers):
    return sum(numbers)/float(len(numbers))
 
def stdev(numbers):
    avg = mean(numbers)
    variance = sum([pow(x-avg,2) for x in numbers])/float(len(numbers)-1)
    return math.sqrt(variance)

# numbers = [1,2,3,4,5]
# print('Summary of {0}: mean={1}, stdev={2}').format(numbers, mean(numbers), stdev(numbers))

# %%
def summarize(dataset):
    summaries = [(mean(attribute), stdev(attribute)) for attribute in zip(*dataset)]
    return summaries

# %%
summary=summarize(dataset)
print('Attribute summaries: {0}').format(summary)
# Out:
# Attribute summaries: [(69.849999999999994, 70.88855226413686), (198.15000000000001, 126.17459707630702), (130.05000000000001, 22.96330023961575), (559.75, 254.76859985815406), (215.5, 72.3300185189204), (37.25, 69.32750270692684), (168.59999999999999, 81.63487386882487), (114.5, 23.67432542250204), (258.75, 97.47975498317047)]

# %%
def summarizeByClass(dataset,labels):
    separated = separateByClass(dataset,labels)
    summaries = {}
    for classValue, instances in separated.iteritems():
        summaries[classValue] = summarize(instances)
    return summaries

# %%
summary = summarizeByClass(dataset,labels)
print('Summary by class value: {0}').format(summary)
# Out:
# Summary by class value: {'behminyan': [(38.399999999999999, 28.86693610343848), (127.59999999999999, 14.876155417311288), (137.40000000000001, 7.602631123499285), (187.19999999999999, 13.989281611290838), (179.59999999999999, 7.602631123499285), (81.200000000000003, 13.516656391282572), (128.59999999999999, 23.70232056149777), (85.799999999999997, 7.949842765740716), (207.19999999999999, 8.955445270895243), (120.8, 7.429670248402684)], 'changsheng': [(32.299999999999997, 16.58010856418015), (134.09999999999999, 34.180728813502824), (126.0, 25.113077602449817), (710.70000000000005, 154.85480654829902), (233.09999999999999, 96.87156445521049), (-26.300000000000001, 23.958528984708373), (123.0, 14.102797200870786), (134.5, 12.47441826744282), (275.39999999999998, 114.47581015704195), (132.30000000000001, 93.46544221737193)], 'jeremyong': [(176.40000000000001, 58.8667987918487), (396.80000000000001, 83.45777375415666), (130.80000000000001, 30.310064335134626), (630.39999999999998, 132.1431042468732), (216.19999999999999, 35.947183477986144), (120.40000000000001, 14.223220451079285), (299.80000000000001, 43.939731451159325), (103.2, 7.726577508832744), (277.0, 105.54146104730596), (113.40000000000001, 21.743964679883014)]}

# %%
def calculateProbability(x, mean, stdev):
    exponent = math.exp(-(math.pow(x-mean,2)/(2*math.pow(stdev,2))))
    return (1 / (math.sqrt(2*math.pi) * stdev)) * exponent

# %%
x = 71.5
mean = 73
stdev = 6.2
probability = calculateProbability(x, mean, stdev)
print('Probability of belonging to this class: {0}').format(probability)
# Out:
# Probability of belonging to this class: 0.0624896575937

# %%
def calculateClassProbabilities(summaries, inputVector):
    probabilities = {}
    for classValue, classSummaries in summaries.iteritems():
        probabilities[classValue] = 1
        for i in range(len(classSummaries)):
            mean, stdev = classSummaries[i]
            x = inputVector[i]
            probabilities[classValue] *= calculateProbability(x, mean, stdev)
    return probabilities
